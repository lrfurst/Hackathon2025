# %% [markdown]
# # 📊 Story 1_1-2: STORY 1.2: Definição do MVP de Features
# **Gerado por:** Ananda Matos (Líder Product/Data)
# **Data:** 15/01/2026 22:08
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print('✅ Ambiente de Produção Carregado')
