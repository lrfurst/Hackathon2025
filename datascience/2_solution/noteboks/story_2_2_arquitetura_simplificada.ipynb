# %% [markdown]
# # 📌 STORY 2.2: Plano de Desenvolvimento Acelerado (24h)
#
# **Responsável:** @ananda.matos
# **Data de criação:** `{{Data Atual}}`
# **Objetivo:** Criar plano executável para uma sprint de 24 horas de desenvolvimento focado, garantindo entrega funcional dentro do prazo.
# **Aprendizado anterior:** Divisão clara de tarefas acelera desenvolvimento paralelo e reduz atritos de integração.
#
# ---
#
# ## 🎯 Visão Geral
#
# Este plano define uma estratégia de desenvolvimento intensivo de 24 horas, dividida em marcos de 6 horas, com alocação clara de responsabilidades, ambiente pré-configurado e plano de contingência para mitigar riscos. O foco é iterar rapidamente e ter um MVP (Minimum Viable Product) funcional ao final do ciclo.
#
# ---
#
# ## 📅 T2.2.1: Cronograma Detalhado (24h)
#
# | Período  | Duração | Marcos Principais                                                                                             |
# |----------|---------|---------------------------------------------------------------------------------------------------------------|
# | **Fase 1** | 0h–6h   | Setup do ambiente, definição de dados, início do desenvolvimento paralelo das três frentes.                  |
# | **Fase 2** | 6h–12h  | Desenvolvimento das funcionalidades principais, primeiros treinos de modelo, criação de endpoints de API.     |
# | **Fase 3** | 12h–18h | Integração inicial, ajustes de compatibilidade, otimização do modelo e validação de métricas.                |
# | **Fase 4** | 18h–24h | Integração final, testes end-to-end, ajustes de contingência (se necessário) e preparação da demonstração.    |
#
# **Buffer programado:**
# - 1h de buffer a cada 6h para problemas inesperados (total de 4h de buffer distribuído).
# - Janela de integração dedicada: **4 horas** nas fases 3 e 4.
#
# ---
#
# ## 👥 T2.2.2: Divisão de Trabalho por Pessoa
#
# **Time:** 3 desenvolvedores/data scientists.
#
# | Pessoa | Responsabilidade Principal                                                                      | Tarefas Específicas                                                                                                                                 |
# |--------|--------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Pessoa 1** | Feature engineering e transformação                                                            | - Análise exploratória inicial<br>- Limpeza e normalização dos dados<br>- Criação de features relevantes<br>- Documentação do dicionário de dados   |
# | **Pessoa 2** | Treino de modelo e otimização                                                                  | - Seleção do modelo inicial (ex: RandomForest, XGBoost)<br>- Validação cruzada e ajuste de hiperparâmetros<br>- Avaliação de métricas (precisão, recall)<br>- Versionamento do modelo |
# | **Pessoa 3** | API e integração com backend                                                                   | - Criação de endpoints REST (FastAPI/Flask)<br>- Integração com o modelo treinado<br>- Conexão com banco de dados ou sistema existente<br>- Documentação da API |
#
# **Pontos de sincronização obrigatórios:**
# - **6h:** Alinhamento sobre formato dos dados e features.
# - **12h:** Revisão do desempenho inicial do modelo e definição de ajustes.
# - **18h:** Teste de integração entre API e modelo.
# - **22h:** Preparação final e validação da demo.
#
# ---
#
# ## ⚠️ T2.2.3: Plano de Contingência
#
# | Cenário de Risco                      | Ação Imediata                                                                                             | Saída Esperada                                                                 |
# |---------------------------------------|-----------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------|
# | Modelo complexo não converge ou é muito lento | Substituir por `LogisticRegression` ou modelo mais simples.                                              | Modelo funcional com recall aceitável (>0.70).                                |
# | API em Python apresenta instabilidade | Criar `mock responses` para continuar o desenvolvimento do frontend/consumo.                              | Fluxo de desenvolvimento não é bloqueado.                                     |
# | Recall abaixo de 0.70                 | Ajustar threshold de classificação ou balancear pesos das classes.                                        | Recall atinge o mínimo desejado para a demo.                                  |
# | Tempo insuficiente para integração completa | Focar em demo com dados fake ou pré-processados, garantindo visibilidade do fluxo completo.               | Demonstração funcional mesmo sem backend real.                                |
# | Falha no ambiente Docker              | Usar ambiente local com `requirements.txt` e script de setup alternativo.                                 | Equipe consegue desenvolver sem container.                                    |
#
# ---
#
# ## 🔧 T2.2.4: Setup do Ambiente de Desenvolvimento
#
# ### ✅ Pré-requisitos
# - Python 3.9+
# - Git
# - Docker (opcional, mas recomendado)
#
# ### 📦 Passos para configuração:
#
# #### 1. Criar `requirements.txt` mínimo:
# ```txt
# pandas==1.5.0
# scikit-learn==1.2.0
# fastapi==0.95.0
# uvicorn==0.21.0
# docker==6.0.0
# ```
#
# #### 2. Setup Docker básico para API:
# ```dockerfile
# FROM python:3.9-slim
# WORKDIR /app
# COPY requirements.txt .
# RUN pip install --no-cache-dir -r requirements.txt
# COPY . .
# CMD ["uvicorn", "main:app", "--host", "0.0.0.0", "--port", "8000"]
# ```
#
# #### 3. Git workflow simplificado:
# ```bash
# # Estrutura de branches:
# main          # apenas versões estáveis
# develop       # integração contínua
# feature/*     # branches de tarefas (ex: feature/engineering, feature/api)
# ```
#
# #### 4. Scripts de desenvolvimento rápido:
# - `setup_dev_env.sh` (ver entregáveis)
# - `run_training.py` (automatiza treino do modelo)
# - `start_api.sh` (sobe API local)
#
# ---
#
# ## 📁 Entregáveis
#
# | Arquivo                                         | Descrição                                                                                     | Responsável      |
# |-------------------------------------------------|-----------------------------------------------------------------------------------------------|------------------|
# | `datascience/2_solution/plan/development_plan_24h.md` | Este documento, detalhando cronograma, divisão de tarefas e contingências.                  | @ananda.matos    |
# | `datascience/2_solution/plan/task_assignment.md`     | Detalhamento diário das tarefas de cada pessoa, com checkpoints e dependências.              | Todos            |
# | `datascience/2_solution/scripts/setup_dev_env.sh`    | Script para configurar ambiente local com todos os pacotes e estruturas necessárias em 15 min. | Pessoa 3         |
#
# ---
#
# ## ✅ Critérios de Sucesso
#
# 1. ✅ MVP funcional após 24h.
# 2. ✅ Modelo com recall > 0.70 (ou modelo de contingência ativado).
# 3. ✅ API respondendo a requests básicos.
# 4. ✅ Código versionado e documentação mínima das decisões.
# 5. ✅ Demo preparada (com dados reais ou simulados).
#
# ---
#
# ## 📌 Notas Finais
#
# - Comunicação constante via canal dedicado (Slack/Teams).
# - Revisões a cada marco para evitar desalinhamento.
# - Foco em funcionalidade, não em perfeição.
# - Documentar problemas e soluções para aprendizado futuro.
#
# **“Feito é melhor que perfeito.”** – Mantra do desenvolvimento acelerado.
#
# ---
#
# **Última atualização:** `{{Data Atual}}`
# **Próxima revisão:** Após 24h de desenvolvimento.
